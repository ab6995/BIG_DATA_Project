# %%
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import os
import pandas as pd
import time
import bokeh.io, bokeh.plotting, bokeh.models, bokeh.charts
from bokeh.models import DatetimeTickFormatter
bokeh.io.output_notebook()
from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_file
from bokeh.charts import Bar, output_file, show
from bokeh.charts import Histogram, output_file, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)
from bokeh.resources import CDN
from bokeh.embed import components, autoload_static, autoload_server
import folium


# %matplotlib inline
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1a50e912-04a2-4eed-a088-5e07bce17e4f">Loading BokehJS ...</span>
#     </div>

# %%
df_bronx_assault_all = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/bronx-assault-all.csv", names = ["lat","long"])
df_bronx_assault_all["lat"] = df_bronx_assault_all["lat"].str.replace("(","")
df_bronx_assault_all["long"] = df_bronx_assault_all["long"].str.replace(")","")
df_bronx_assault_all['lat'] = df_bronx_assault_all['lat'].astype(float)
df_bronx_assault_all['long'] = df_bronx_assault_all['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_bronx_assault_all.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index
state_geo = r'locationplot/police_precincts.json'

new_df = new_df.head(100)
map = folium.Map(location=[40.8448, -73.8648], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#bronx places for freq occuring assaults in february
df_bronx_assault_feb = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/bronx-assault-feb.csv", names = ["lat","long"])
df_bronx_assault_feb["lat"] = df_bronx_assault_feb["lat"].str.replace("(","")
df_bronx_assault_feb["long"] = df_bronx_assault_feb["long"].str.replace(")","")
df_bronx_assault_feb['lat'] = df_bronx_assault_feb['lat'].astype(float)
df_bronx_assault_feb['long'] = df_bronx_assault_feb['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_bronx_assault_feb.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index
state_geo = r'locationplot/police_precincts.json'

new_df = new_df.head(10)
map = folium.Map(location=[40.8448, -73.8648], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_bronx_assault_summer = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/bronx-assault-summer.csv", names = ["lat","long"])
df_bronx_assault_summer["lat"] = df_bronx_assault_summer["lat"].str.replace("(","")
df_bronx_assault_summer["long"] = df_bronx_assault_summer["long"].str.replace(")","")
df_bronx_assault_summer['lat'] = df_bronx_assault_summer['lat'].astype(float)
df_bronx_assault_summer['long'] = df_bronx_assault_summer['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_bronx_assault_summer.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.8448, -73.8648], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_bronx_larceny_summer = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/bronx-larceny-summer.csv", names = ["lat","long"])
df_bronx_larceny_summer["lat"] = df_bronx_larceny_summer["lat"].str.replace("(","")
df_bronx_larceny_summer["long"] = df_bronx_larceny_summer["long"].str.replace(")","")
df_bronx_larceny_summer['lat'] = df_bronx_larceny_summer['lat'].astype(float)
df_bronx_larceny_summer['long'] = df_bronx_larceny_summer['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_bronx_larceny_summer.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.8448, -73.8648], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_bronx_larceny_feb = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/bronx-larceny-feb.csv", names = ["lat","long"])
df_bronx_larceny_feb["lat"] = df_bronx_larceny_feb["lat"].str.replace("(","")
df_bronx_larceny_feb["long"] = df_bronx_larceny_feb["long"].str.replace(")","")
df_bronx_larceny_feb['lat'] = df_bronx_larceny_feb['lat'].astype(float)
df_bronx_larceny_feb['long'] = df_bronx_larceny_feb['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_bronx_larceny_feb.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.8448, -73.8648], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_brooklyn_assault_feb = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/brooklyn-assault-feb.csv", names = ["lat","long"])
df_brooklyn_assault_feb["lat"] = df_brooklyn_assault_feb["lat"].str.replace("(","")
df_brooklyn_assault_feb["long"] = df_brooklyn_assault_feb["long"].str.replace(")","")
df_brooklyn_assault_feb['lat'] = df_brooklyn_assault_feb['lat'].astype(float)
df_brooklyn_assault_feb['long'] = df_brooklyn_assault_feb['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_brooklyn_assault_feb.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.6782, -73.9442], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_brooklyn_assault_summer = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/brooklyn-assault-summer.csv", names = ["lat","long"])
df_brooklyn_assault_summer["lat"] = df_brooklyn_assault_summer["lat"].str.replace("(","")
df_brooklyn_assault_summer["long"] = df_brooklyn_assault_summer["long"].str.replace(")","")
df_brooklyn_assault_summer['lat'] = df_brooklyn_assault_summer['lat'].astype(float)
df_brooklyn_assault_summer['long'] = df_brooklyn_assault_summer['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_brooklyn_assault_summer.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.6782, -73.9442], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_brooklyn_larceny_feb = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/brooklyn-larceny-feb.csv", names = ["lat","long"])
df_brooklyn_larceny_feb["lat"] = df_brooklyn_larceny_feb["lat"].str.replace("(","")
df_brooklyn_larceny_feb["long"] = df_brooklyn_larceny_feb["long"].str.replace(")","")
df_brooklyn_larceny_feb['lat'] = df_brooklyn_larceny_feb['lat'].astype(float)
df_brooklyn_larceny_feb['long'] = df_brooklyn_larceny_feb['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_brooklyn_larceny_feb.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.6782, -73.9442], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_brooklyn_larceny_summer = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/brooklyn-larceny-summer.csv", names = ["lat","long"])
df_brooklyn_larceny_summer["lat"] = df_brooklyn_larceny_summer["lat"].str.replace("(","")
df_brooklyn_larceny_summer["long"] = df_brooklyn_larceny_summer["long"].str.replace(")","")
df_brooklyn_larceny_summer['lat'] = df_brooklyn_larceny_summer['lat'].astype(float)
df_brooklyn_larceny_summer['long'] = df_brooklyn_larceny_summer['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_brooklyn_larceny_summer.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.6782, -73.9442], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_manhattan_larceny_feb = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/manhattan-larceny-feb.csv", names = ["lat","long"])
df_manhattan_larceny_feb["lat"] = df_manhattan_larceny_feb["lat"].str.replace("(","")
df_manhattan_larceny_feb["long"] = df_manhattan_larceny_feb["long"].str.replace(")","")
df_manhattan_larceny_feb['lat'] = df_manhattan_larceny_feb['lat'].astype(float)
df_manhattan_larceny_feb['long'] = df_manhattan_larceny_feb['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_manhattan_larceny_feb.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.7831, -73.9712], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_manhattan_larceny_summer = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/manhattan-larceny-summer.csv", names = ["lat","long"])
df_manhattan_larceny_summer["lat"] = df_manhattan_larceny_summer["lat"].str.replace("(","")
df_manhattan_larceny_summer["long"] = df_manhattan_larceny_summer["long"].str.replace(")","")
df_manhattan_larceny_summer['lat'] = df_manhattan_larceny_summer['lat'].astype(float)
df_manhattan_larceny_summer['long'] = df_manhattan_larceny_summer['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_manhattan_larceny_summer.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.7831, -73.9712], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_queens_larceny_feb = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/queens-larceny-feb.csv", names = ["lat","long"])
df_queens_larceny_feb["lat"] = df_queens_larceny_feb["lat"].str.replace("(","")
df_queens_larceny_feb["long"] = df_queens_larceny_feb["long"].str.replace(")","")
df_queens_larceny_feb['lat'] = df_queens_larceny_feb['lat'].astype(float)
df_queens_larceny_feb['long'] = df_queens_larceny_feb['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_queens_larceny_feb.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.7282, -73.7949], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_queens_larceny_summer = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/queens-larceny-summer.csv", names = ["lat","long"])
df_queens_larceny_summer["lat"] = df_queens_larceny_summer["lat"].str.replace("(","")
df_queens_larceny_summer["long"] = df_queens_larceny_summer["long"].str.replace(")","")
df_queens_larceny_summer['lat'] = df_queens_larceny_summer['lat'].astype(float)
df_queens_larceny_summer['long'] = df_queens_larceny_summer['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_queens_larceny_summer.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.7282, -73.7949], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_queens_assault_summer = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/queens-assault-summer.csv", names = ["lat","long"])
df_queens_assault_summer["lat"] = df_queens_assault_summer["lat"].str.replace("(","")
df_queens_assault_summer["long"] = df_queens_assault_summer["long"].str.replace(")","")
df_queens_assault_summer['lat'] = df_queens_assault_summer['lat'].astype(float)
df_queens_assault_summer['long'] = df_queens_assault_summer['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_queens_assault_summer.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.7282, -73.7949], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_queens_assault_feb = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/queens-assault-feb.csv", names = ["lat","long"])
df_queens_assault_feb["lat"] = df_queens_assault_feb["lat"].str.replace("(","")
df_queens_assault_feb["long"] = df_queens_assault_feb["long"].str.replace(")","")
df_queens_assault_feb['lat'] = df_queens_assault_feb['lat'].astype(float)
df_queens_assault_feb['long'] = df_queens_assault_feb['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_queens_assault_feb.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.7282, -73.7949], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_si_feb = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/staten-assault-feb.csv", names = ["lat","long"])
df_si_feb["lat"] = df_si_feb["lat"].str.replace("(","")
df_si_feb["long"] = df_si_feb["long"].str.replace(")","")
df_si_feb['lat'] = df_si_feb['lat'].astype(float)
df_si_feb['long'] = df_si_feb['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_si_feb.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(10)
map = folium.Map(location=[40.5795, -74.1502], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_si_summer = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/staten-assault-summer.csv", names = ["lat","long"])
df_si_summer["lat"] = df_si_summer["lat"].str.replace("(","")
df_si_summer["long"] = df_si_summer["long"].str.replace(")","")
df_si_summer['lat'] = df_si_summer['lat'].astype(float)
df_si_summer['long'] = df_si_summer['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_si_summer.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(20)
map = folium.Map(location=[40.5795, -74.1502], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_si_larceny_summer = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/staten-larceny-summer.csv", names = ["lat","long"])
df_si_larceny_summer["lat"] = df_si_larceny_summer["lat"].str.replace("(","")
df_si_larceny_summer["long"] = df_si_larceny_summer["long"].str.replace(")","")
df_si_larceny_summer['lat'] = df_si_larceny_summer['lat'].astype(float)
df_si_larceny_summer['long'] = df_si_larceny_summer['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_si_larceny_summer.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(20)
map = folium.Map(location=[40.5795, -74.1502], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_si_larceny_feb = pd.read_csv("/Users/ashishbansal/Downloads/ds1004-big-data-final-project-master/Datasets/locationplot/staten-larceny-feb.csv", names = ["lat","long"])
df_si_larceny_feb["lat"] = df_si_larceny_feb["lat"].str.replace("(","")
df_si_larceny_feb["long"] = df_si_larceny_feb["long"].str.replace(")","")
df_si_larceny_feb['lat'] = df_si_larceny_feb['lat'].astype(float)
df_si_larceny_feb['long'] = df_si_larceny_feb['long'].astype(float)
# get the coordinates with the most incidents of assault in bronx
new_df =  pd.core.frame.DataFrame({'count' : df_si_larceny_feb.groupby(["lat", "long"] ).size()}).reset_index().sort_values('count',ascending = False)
new_df['index'] = new_df.index

new_df = new_df.head(20)
map = folium.Map(location=[40.5795, -74.1502], zoom_start=13)
new_df.apply(lambda row:folium.Marker(location=[row["lat"], row["long"]]).add_to(map),axis = 1)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
